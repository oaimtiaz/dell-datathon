# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime, timedelta

# %%
all_data = pd.read_csv("all-data.csv")

# %%
target_columns["support-quarantine", "wearing-masks", ""
# Out:
#            Date  yoy reservations %  New Cases  support-quarantine  \
# 0    2020-02-18                0.00        NaN                 NaN
# 1    2020-02-19               -6.00        NaN                 NaN
# 2    2020-02-20                0.00        NaN                 NaN
# 3    2020-02-21                2.00        NaN                 NaN
# 4    2020-02-22                1.00        NaN                 NaN
# ..          ...                 ...        ...                 ...
# 236  2020-10-11              -15.81     2262.0                 NaN
# 237  2020-10-12              -37.19     2384.0                56.0
# 238  2020-10-13              -39.68     5050.0                 NaN
# 239  2020-10-14              -39.02     4564.0                 NaN
# 240  2020-10-15              -33.04     4615.0                 NaN
#
#      wearing-masks  avoiding-crowds % of hospital capacity for covid  \
# 0              NaN              NaN                              NaN
# ...
