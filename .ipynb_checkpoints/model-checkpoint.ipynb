# %%
import pandas as pd 
import numpy as np
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from sklearn.tree import DecisionTreeRegressor

# %%
X = pd.read_csv("all-data.csv").drop("Date", axis=1)

# %%
X
# Out:
#      Index  yoy reservations %  New Cases  support-quarantine  wearing-masks  \
# 0        0             -100.00        923           69.000000      46.142857
# 1        1              -99.95        422           69.000000      49.000000
# 2        2             -100.00        718           68.571429      50.285714
# 3        3             -100.00        868           68.142857      51.571429
# 4        4             -100.00        963           67.714286      52.857143
# ..     ...                 ...        ...                 ...            ...
# 182    182              -15.81       2262           55.833333      78.666667
# 183    183              -37.19       2384           56.000000      79.000000
# 184    184              -39.68       5050           56.000000      79.000000
# 185    185              -39.02       4564           56.000000      79.000000
# 186    186              -33.04       4615           56.000000      79.000000
#
#      avoiding-crowds  % of hospital capacity for covid  # of hospitalisations  \
# 0          74.571429                               0.9                     22
# 1          75.000000                               1.2                     26
# 2          74.714286                               1.1                     28
# 3          74.428571                               1.3                     30
# 4          74.142857                               0.9                     22
# ..               ...                               ...                    ...
# 182        65.000000                               2.2                     93
# 183        65.000000                               2.2                     91
# 184        65.000000                               2.3                     96
# 185        65.000000                               2.4                     99
# 186        65.000000                               2.3                     99
#
#      % of hospitalizations for covid  # ICU Beds for covid  Total_Reported
# 0                              815.0                    12           815.0
# 1                              898.0                    15           898.0
# 2                              943.0                    16           943.0
# 3                             1020.0                    17          1020.0
# 4                             1074.0                    14          1074.0
# ..                               ...                   ...             ...
# 182                          31208.0                    30         31208.0
# 183                          31341.0                    32         31341.0
# 184                          31447.5                    34         31447.5
# 185                          31554.0                    34         31554.0
# 186                          31650.0                    39         31650.0
#
# [187 rows x 11 columns]

# %%
useable_X = X.loc[X["Index"] < len(X)-60]
useable_y = X.loc[X["Index"] > 59]["New Cases"]
predict_X = X.loc[X["Index"] >= len(X) - 60]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(useable_X, useable_y, test_size = 0.3, train_size = .5)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
print(tree.score(X_train, y_train))
print(tree.score(X_test, y_test))
print(tree.score(useable_X, useable_y))
# Out:
# 1.0
# 0.574675324271575
# 0.7146852405745403

# %%
def plot_model(model, X_data, y, predict):
    fig, ax = plt.subplots(1, 1, figsize=(5,5))
    # ax.scatter(predict["Index"], model.predict(predict))
    ax.plot(predict["Index"], model.predict(predict))
    ax.set_title("Prediction")
    
    fig2, ax2 = plt.subplots(1, 1, figsize=(5,5))
    ax2.scatter(X_data["Index"], y)
    ax2.plot(X_data["Index"], model.predict(X_data))
    ax2.set_title("Training Data")

# %%
plot_model(tree, useable_X, useable_y, predict_X)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
print(forest.score(X_train, y_train))
print(forest.score(X_test, y_test))
print(forest.score(useable_X, useable_y))
# Out:
# 0.9618373576843887
# 0.6961376256445684
# 0.7810329877372524

# %%
plot_model(forest, useable_X, useable_y, predict_X)

# %%
from sklearn.svm import SVR

# %%
svr = SVR(kernel='rbf', degree = 20)
svr.fit(X_train, y_train)

# %%
print(svr.score(X_train, y_train))
print(svr.score(X_test, y_test))
print(svr.score(useable_X, useable_y))

# %%
plot_model(svr, useable_X, useable_y, predict_X)
