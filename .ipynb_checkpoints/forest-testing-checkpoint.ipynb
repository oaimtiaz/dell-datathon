# %%
import pandas as pd 
import numpy as np
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
X = pd.read_csv("all-data.csv").drop("Date", axis=1)

# %%
useable_X = X.loc[X["Index"] < len(X)-60]
useable_y = X.loc[X["Index"] > 59]["New Cases"]
predict_X = X.loc[X["Index"] >= len(X) - 60]

# %%
presentable = useable_X.drop("% of hospitalizations for covid", axis=1)
presentable
# Out:
#      Index  yoy reservations %  New Cases  support-quarantine  wearing-masks  \
# 0        0             -100.00        923           69.000000      46.142857
# 1        1              -99.95        422           69.000000      49.000000
# 2        2             -100.00        718           68.571429      50.285714
# 3        3             -100.00        868           68.142857      51.571429
# 4        4             -100.00        963           67.714286      52.857143
# ..     ...                 ...        ...                 ...            ...
# 122    122              -52.27       6200           57.428571      79.857143
# 123    123              -49.02       6755           57.142857      79.285714
# 124    124              -41.60       7018           56.857143      78.714286
# 125    125              -36.90       8245           56.571429      78.142857
# 126    126              -36.89       6204           56.285714      77.571429
#
#      avoiding-crowds  % of hospital capacity for covid  # of hospitalisations  \
# 0          74.571429                               0.9                     22
# 1          75.000000                               1.2                     26
# 2          74.714286                               1.1                     28
# 3          74.428571                               1.3                     30
# 4          74.142857                               0.9                     22
# ..               ...                               ...                    ...
# 122        68.285714                               9.5                    290
# 123        67.428571                               9.7                    310
# 124        66.571429                               9.0                    295
# 125        65.714286                               8.8                    287
# 126        64.857143                               8.6                    272
#
#      # ICU Beds for covid  Total_Reported
# 0                      12           815.0
# 1                      15           898.0
# 2                      16           943.0
# 3                      17          1020.0
# 4                      14          1074.0
# ..                    ...             ...
# 122                   106         24020.0
# 123                   112         24324.0
# 124                   106         24482.0
# 125                   102         24621.0
# 126                   102         24758.0
#
# [127 rows x 10 columns]

# %%
useable_X.describe()
# Out:
#             Index  yoy reservations %     New Cases  support-quarantine  \
# count  127.000000          127.000000    127.000000          127.000000
# mean    63.000000          -66.885827   4118.448819           57.208661
# std     36.805797           18.677804   3411.012198            4.933981
# min      0.000000         -100.000000    422.000000           50.000000
# 25%     31.500000          -81.675000   1035.000000           53.571429
# 50%     63.000000          -61.940000   2331.000000           56.000000
# 75%     94.500000          -54.280000   7169.500000           59.750000
# max    126.000000           -9.390000  10791.000000           69.000000
#
#        wearing-masks  avoiding-crowds  % of hospital capacity for covid  \
# count     127.000000       127.000000                        127.000000
# mean       69.316085        66.831271                          6.728346
# std         6.976647         3.456941                          5.391188
# min        46.142857        60.000000                          0.400000
# 25%        65.844828        64.535714                          2.300000
# 50%        69.000000        65.785714                          3.700000
# 75%        75.285714        68.931034                         11.550000
# max        81.000000        75.000000                         18.800000
#
#        # of hospitalisations  % of hospitalizations for covid  \
# count              127.00000                       127.000000
# mean               219.11811                      9002.649606
# std                179.89272                      8137.568099
# min                  7.00000                         0.000000
# 25%                 68.00000                      2353.500000
# 50%                123.00000                      4595.000000
# 75%                366.50000                     17080.000000
# max                577.00000                     24758.000000
#
#        # ICU Beds for covid  Total_Reported
# count            127.000000      127.000000
# mean              78.976378     9062.598425
# std               60.423960     8098.672137
# min                3.000000      815.000000
# 25%               29.000000     2411.500000
# 50%               50.000000     4682.000000
# 75%              130.000000    17080.000000
# max              254.000000    24758.000000

# %%
X_train, X_test, y_train, y_test = train_test_split(useable_X, useable_y, test_size = 0.3, train_size = .5)

# %%
features = X.columns
# Out:
# Index(['Index', 'yoy reservations %', 'New Cases', 'support-quarantine',
#        'wearing-masks', 'avoiding-crowds', '% of hospital capacity for covid',
#        '# of hospitalisations', '% of hospitalizations for covid',
#        '# ICU Beds for covid', 'Total_Reported'],
#       dtype='object')

# %%
def plot_model(model):
    fig, ax = plt.subplots(1, 1, figsize=(5,5))
    # ax.set_ylim([0, 1200])
    # ax.scatter(predict["Index"], model.predict(predict))
    ax.plot(predict_X["Index"], model.predict(predict_X))
    ax.set_title("Prediction")
    plt.savefig("sqrt_model_prediction.png")

    
    fig2, ax2 = plt.subplots(1, 1, figsize=(5,5))
    # ax2.set_ylim([0, 1200])
    ax2.scatter(useable_X["Index"], useable_y)
    ax2.plot(useable_X["Index"], model.predict(useable_X))
    ax2.set_title("Training Data")

    plt.savefig("sqrt_model_past.png")

# %%
def print_scores(model):
    print(model.score(X_train, y_train))
    print(model.score(X_test, y_test))
    print(model.score(useable_X, useable_y))

# %%
forest = RandomForestRegressor()
forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
print_scores(forest)
# Out:
# 0.9359008382701085
# 0.7874653942014529
# 0.8366798046043229

# %%
plot_model(forest)

# %%
mae_forest = RandomForestRegressor(criterion="mae")
mae_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(criterion='mae')

# %%
print_scores(mae_forest)
# Out:
# 0.9335986740522944
# 0.754955341766756
# 0.8185297785294497

# %%
sqrt_forest = RandomForestRegressor(max_features="sqrt")
sqrt_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features='sqrt')

# %%
print_scores(sqrt_forest)
# Out:
# 0.9283287802563456
# 0.7918426809379412
# 0.8305416863281254

# %%
plot_model(sqrt_forest)

# %%
importance = sqrt_forest.feature_importances_ 

for i, v in enumerate(importance): 
    print("Feature %0d: %s, Score %.5f" % (i, X.columns[i], v))
# Out:
# Feature 0: Index, Score 0.10528
# Feature 1: yoy reservations %, Score 0.05697
# Feature 2: New Cases, Score 0.07600
# Feature 3: support-quarantine, Score 0.07531
# Feature 4: wearing-masks, Score 0.12206
# Feature 5: avoiding-crowds, Score 0.05752
# Feature 6: % of hospital capacity for covid, Score 0.07601
# Feature 7: # of hospitalisations, Score 0.07871
# Feature 8: % of hospitalizations for covid, Score 0.17053
# Feature 9: # ICU Beds for covid, Score 0.06131
# Feature 10: Total_Reported, Score 0.12030

# %%
features = [] 
bad_i
temp = useable_X.columns
for x in range(len(temp)):
    if col != "% of hospitalizations for covid":
        features.append(col)
    else:
        bad_i = x

# %%
plt.bar([x for x in range(len(importance) - 1)], importance)
plt.xticks([x for x in range(len(importance) - 1)], labels = features, rotation=45, fontsize='12', horizontalalignment='right')
plt.tight_layout()
plt.savefig("feature_importance.png")

# %%
log_forest = RandomForestRegressor(max_features="log2")
log_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_features='log2')

# %%
print_scores(log_forest)
# Out:
# 0.9317322464996552
# 0.7873709469703686
# 0.8330214251521545
